# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Test: a simple model

# %%
from hackaton_eet.data.loaders import get_data
from hackaton_eet.data.transformers import align_data

# %% [markdown]
# First, let's get the data. To maket his easier, a helper function `get_data` has been created. As inputs, this function expects a dictionary of your desired datasets, their columns and lags. Note that all lags are given in terms of 15 minutes, and the dates on the column are the day you are trying to predict.
#
# Since we run the model each day at 10:00:00, this means that lag 1 is 09:45:00, and so on.
#
# The code knows of each set which bits are known in advance and which parts are only known after the fact, and will only return the data you have available at each time. It is highly recommended to use this function instead of writing your own.

# %%
feature_datasets = {
    'tennet.verrekenprijzen': {
        'lags': [1,],  # Lags are now days. Makes working with them easier
        'columns': ['invoeden', 'Afnemen']
    },
#     'reuters.dayahead' : {
#         'columns': ['Wind_NLD', 'CON_NLD'],
#         'lags': [1,]
#     }
}
target_dataset = {
    'tennet.target': {
        'columns': ['invoeden', 'Afnemen'],
        'lags': [1, 2]
    }
}

feature_data = get_data(feature_datasets)
target_data = get_data(target_dataset)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/dennis/anaconda/envs/hackaton_eet/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    4295
# -> 4296         mgr = BlockManager(blocks, axes)
#    4297         mgr._consolidate_inplace()
#
# /Users/dennis/anaconda/envs/hackaton_eet/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, blocks, axes, do_integrity_check, fastpath)
#    2794         if do_integrity_check:
# -> 2795             self._verify_integrity()
#    2796
#
# /Users/dennis/anaconda/envs/hackaton_eet/lib/python3.6/site-packages/pandas/core/internals.py in _verify_integrity(self)
#    3005             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 3006                 construction_error(tot_items, block.shape[1:], self.axes)
#    3007         if len(self.items) != tot_items:
#
# /Users/dennis/anaconda/envs/hackaton_eet/lib/python3.6/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    4279     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4280         passed, implied))
#    4281
#
# ValueError: Shape of passed values is (72961, 4), indices imply (72961, 2)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b46e67a0577c> in <module>()
#      17
#      18 feature_data = get_data(feature_datasets)
# ---> 19 target_data = get_data(target_dataset)
#
# /Users/dennis/OneDrive - Eneco Groep/xx.Hackathon/honkeyponkey/hackaton_eet/data/loaders.py in get_data(datasets)
#     146     res = pd.DataFrame()
#     147     for dataset in sets.values():
# --> 148         res = res.append(dataset.get_ptu_lag_data())
#     149     return res
#
# /Users/dennis/OneDrive - Eneco Groep/xx.Hackathon/honkeyponkey/hackaton_eet/data/loaders.py in get_ptu_lag_data(self)
#      92             index=self.get_row_names(),
#      93             columns=self.data.iloc[
# ---> 94                 ptulocs
#      95             ].index
#      96         )
#
# /Users/dennis/anaconda/envs/hackaton_eet/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     304             else:
#     305                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 306                                          copy=copy)
#     307         elif isinstance(data, (list, types.GeneratorType)):
#     308             if isinstance(data, types.GeneratorType):
#
# /Users/dennis/anaconda/envs/hackaton_eet/lib/python3.6/site-packages/pandas/core/frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     481             values = maybe_infer_to_datetimelike(values)
#     482
# --> 483         return create_block_manager_from_blocks([values], [columns, index])
#     484
#     485     @property
#
# /Users/dennis/anaconda/envs/hackaton_eet/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    4301         blocks = [getattr(b, 'values', b) for b in blocks]
#    4302         tot_items = sum(b.shape[0] for b in blocks)
# -> 4303         construction_error(tot_items, blocks[0].shape[1:], axes, e)
#    4304
#    4305
#
# /Users/dennis/anaconda/envs/hackaton_eet/lib/python3.6/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    4278         raise ValueError("Empty data passed with indices specified.")
#    4279     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4280         passed, implied))
#    4281
#    4282
#
# ValueError: Shape of passed values is (72961, 4), indices imply (72961, 2)

# %%
feature_data
# Out:
# datetime                               2014-05-02 02:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.29
# tennet.verrekenprijzen.Afnemen.lag_1                       35.29
#
# datetime                               2014-05-02 02:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      37.63
# tennet.verrekenprijzen.Afnemen.lag_1                       37.63
#
# datetime                               2014-05-02 02:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                       35.6
# tennet.verrekenprijzen.Afnemen.lag_1                        35.6
#
# datetime                               2014-05-02 02:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.01
# tennet.verrekenprijzen.Afnemen.lag_1                       35.01
#
# datetime                               2014-05-02 03:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 03:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 03:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 03:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 04:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 04:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                       34.9
# tennet.verrekenprijzen.Afnemen.lag_1                        34.9
#
# datetime                                         ...              \
# tennet.verrekenprijzen.invoeden.lag_1            ...
# tennet.verrekenprijzen.Afnemen.lag_1             ...
#
# datetime                               2016-05-30 23:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      21.73
# tennet.verrekenprijzen.Afnemen.lag_1                       21.73
#
# datetime                               2016-05-31 00:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      26.69
# tennet.verrekenprijzen.Afnemen.lag_1                       22.78
#
# datetime                               2016-05-31 00:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      26.69
# tennet.verrekenprijzen.Afnemen.lag_1                       26.69
#
# datetime                               2016-05-31 00:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      16.73
# tennet.verrekenprijzen.Afnemen.lag_1                       16.73
#
# datetime                               2016-05-31 00:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                    -150.78
# tennet.verrekenprijzen.Afnemen.lag_1                     -150.78
#
# datetime                               2016-05-31 01:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                     350.12
# tennet.verrekenprijzen.Afnemen.lag_1                      350.12
#
# datetime                               2016-05-31 01:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                       8.13
# tennet.verrekenprijzen.Afnemen.lag_1                        8.13
#
# datetime                               2016-05-31 01:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      20.59
# tennet.verrekenprijzen.Afnemen.lag_1                       20.59
#
# datetime                               2016-05-31 01:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      16.73
# tennet.verrekenprijzen.Afnemen.lag_1                       16.73
#
# datetime                               2016-05-31 02:00:00+02:00
# tennet.verrekenprijzen.invoeden.lag_1                      23.73
# tennet.verrekenprijzen.Afnemen.lag_1                       23.73
#
# [2 rows x 72961 columns]

# %%
target_data

# %%
import pandas as pd
pd.DataFrame(feature_data)
# Out:
# datetime                               2014-05-02 02:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.29
# tennet.verrekenprijzen.Afnemen.lag_1                       35.29
#
# datetime                               2014-05-02 02:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      37.63
# tennet.verrekenprijzen.Afnemen.lag_1                       37.63
#
# datetime                               2014-05-02 02:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                       35.6
# tennet.verrekenprijzen.Afnemen.lag_1                        35.6
#
# datetime                               2014-05-02 02:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.01
# tennet.verrekenprijzen.Afnemen.lag_1                       35.01
#
# datetime                               2014-05-02 03:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 03:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 03:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 03:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 04:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 04:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                       34.9
# tennet.verrekenprijzen.Afnemen.lag_1                        34.9
#
# datetime                                         ...              \
# tennet.verrekenprijzen.invoeden.lag_1            ...
# tennet.verrekenprijzen.Afnemen.lag_1             ...
#
# datetime                               2016-05-30 23:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      21.73
# tennet.verrekenprijzen.Afnemen.lag_1                       21.73
#
# datetime                               2016-05-31 00:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      26.69
# tennet.verrekenprijzen.Afnemen.lag_1                       22.78
#
# datetime                               2016-05-31 00:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      26.69
# tennet.verrekenprijzen.Afnemen.lag_1                       26.69
#
# datetime                               2016-05-31 00:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      16.73
# tennet.verrekenprijzen.Afnemen.lag_1                       16.73
#
# datetime                               2016-05-31 00:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                    -150.78
# tennet.verrekenprijzen.Afnemen.lag_1                     -150.78
#
# datetime                               2016-05-31 01:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                     350.12
# tennet.verrekenprijzen.Afnemen.lag_1                      350.12
#
# datetime                               2016-05-31 01:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                       8.13
# tennet.verrekenprijzen.Afnemen.lag_1                        8.13
#
# datetime                               2016-05-31 01:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      20.59
# tennet.verrekenprijzen.Afnemen.lag_1                       20.59
#
# datetime                               2016-05-31 01:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      16.73
# tennet.verrekenprijzen.Afnemen.lag_1                       16.73
#
# datetime                               2016-05-31 02:00:00+02:00
# tennet.verrekenprijzen.invoeden.lag_1                      23.73
# tennet.verrekenprijzen.Afnemen.lag_1                       23.73
#
# [2 rows x 72961 columns]

# %% [markdown]
# ## Training the model

# %%
feature_data
# Out:
# datetime                               2014-05-02 02:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.29
# tennet.verrekenprijzen.Afnemen.lag_1                       35.29
#
# datetime                               2014-05-02 02:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      37.63
# tennet.verrekenprijzen.Afnemen.lag_1                       37.63
#
# datetime                               2014-05-02 02:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                       35.6
# tennet.verrekenprijzen.Afnemen.lag_1                        35.6
#
# datetime                               2014-05-02 02:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.01
# tennet.verrekenprijzen.Afnemen.lag_1                       35.01
#
# datetime                               2014-05-02 03:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 03:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 03:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 03:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 04:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      35.23
# tennet.verrekenprijzen.Afnemen.lag_1                       35.23
#
# datetime                               2014-05-02 04:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                       34.9
# tennet.verrekenprijzen.Afnemen.lag_1                        34.9
#
# datetime                                         ...              \
# tennet.verrekenprijzen.invoeden.lag_1            ...
# tennet.verrekenprijzen.Afnemen.lag_1             ...
#
# datetime                               2016-05-30 23:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      21.73
# tennet.verrekenprijzen.Afnemen.lag_1                       21.73
#
# datetime                               2016-05-31 00:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      26.69
# tennet.verrekenprijzen.Afnemen.lag_1                       22.78
#
# datetime                               2016-05-31 00:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      26.69
# tennet.verrekenprijzen.Afnemen.lag_1                       26.69
#
# datetime                               2016-05-31 00:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      16.73
# tennet.verrekenprijzen.Afnemen.lag_1                       16.73
#
# datetime                               2016-05-31 00:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                    -150.78
# tennet.verrekenprijzen.Afnemen.lag_1                     -150.78
#
# datetime                               2016-05-31 01:00:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                     350.12
# tennet.verrekenprijzen.Afnemen.lag_1                      350.12
#
# datetime                               2016-05-31 01:15:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                       8.13
# tennet.verrekenprijzen.Afnemen.lag_1                        8.13
#
# datetime                               2016-05-31 01:30:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      20.59
# tennet.verrekenprijzen.Afnemen.lag_1                       20.59
#
# datetime                               2016-05-31 01:45:00+02:00  \
# tennet.verrekenprijzen.invoeden.lag_1                      16.73
# tennet.verrekenprijzen.Afnemen.lag_1                       16.73
#
# datetime                               2016-05-31 02:00:00+02:00
# tennet.verrekenprijzen.invoeden.lag_1                      23.73
# tennet.verrekenprijzen.Afnemen.lag_1                       23.73
#
# [2 rows x 72961 columns]

# %%
target_data
# Out:
# datetime  2014-05-01 02:00:00+02:00  2014-05-01 02:15:00+02:00  \
# invoeden                      35.29                      37.63
# Afnemen                       35.29                      37.63
#
# datetime  2014-05-01 02:30:00+02:00  2014-05-01 02:45:00+02:00  \
# invoeden                       35.6                      35.01
# Afnemen                        35.6                      35.01
#
# datetime  2014-05-01 03:00:00+02:00  2014-05-01 03:15:00+02:00  \
# invoeden                      35.23                      35.23
# Afnemen                       35.23                      35.23
#
# datetime  2014-05-01 03:30:00+02:00  2014-05-01 03:45:00+02:00  \
# invoeden                      35.23                      35.23
# Afnemen                       35.23                      35.23
#
# datetime  2014-05-01 04:00:00+02:00  2014-05-01 04:15:00+02:00  \
# invoeden                      35.23                       34.9
# Afnemen                       35.23                       34.9
#
# datetime            ...              2016-05-30 23:45:00+02:00  \
# invoeden            ...                                  36.23
# Afnemen             ...                                  36.23
#
# datetime  2016-05-31 00:00:00+02:00  2016-05-31 00:15:00+02:00  \
# invoeden                     -41.03                      20.74
# Afnemen                      -41.03                      20.74
#
# datetime  2016-05-31 00:30:00+02:00  2016-05-31 00:45:00+02:00  \
# invoeden                      21.74                    -150.03
# Afnemen                       21.74                    -150.03
#
# datetime  2016-05-31 01:00:00+02:00  2016-05-31 01:15:00+02:00  \
# invoeden                      34.92                      62.68
# Afnemen                     -150.03                      20.74
#
# datetime  2016-05-31 01:30:00+02:00  2016-05-31 01:45:00+02:00  \
# invoeden                      20.74                      24.12
# Afnemen                       20.74                      24.12
#
# datetime  2016-05-31 02:00:00+02:00
# invoeden                      24.15
# Afnemen                       24.15
#
# [2 rows x 73057 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, explained_variance_score

# %%
X = feature_data.fillna(0).values
y = target_data.fillna(0).values

X, y = align_data(X, y)

X, y = X.T, y.T

X_train, X_test = X[:250], X[250:]
y_train, y_test = y[:250], y[250:]

# %%
est = RandomForestRegressor(
    n_estimators=500,
    max_depth=5,
    n_jobs=-1,
).fit(X_train, y_train)
y_pred = est.predict(X_test)

# %% [markdown]
# So, did it work?

# %%
print("MAE: %.2f" % mean_absolute_error(y_test, y_pred))
print("VAF: %.2f" % explained_variance_score(y_test, y_pred))
# Out:
# MAE: 29.86
# VAF: -0.03

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(y_pred[:, 1] - y_test[:, 1])
